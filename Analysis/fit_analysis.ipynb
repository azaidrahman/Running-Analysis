# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- --------------
# aiohappyeyeballs          2.3.5
# aiohttp                   3.10.3
# aiosignal                 1.3.1
# anyio                     4.4.0
# appdirs                   1.4.4
# argon2-cffi               23.1.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.3.0
# asttokens                 2.4.1
# async-lru                 2.0.4
# attrs                     23.2.0
# autograd                  1.6.2
# autograd-gamma            0.5.0
# babel                     2.16.0
# babelfish                 0.6.0
# beautifulsoup4            4.12.3
# bleach                    6.1.0
# certifi                   2023.11.17
# cffi                      1.17.0
# chardet                   5.2.0
# charset-normalizer        3.3.2
# click                     8.1.7
# colorama                  0.4.6
# comm                      0.2.2
# contourpy                 1.2.0
# cycler                    0.12.1
# debugpy                   1.8.1
# decorator                 5.1.1
# defusedxml                0.7.1
# distlib                   0.3.8
# dogpile.cache             1.3.0
# enzyme                    0.4.1
# et-xmlfile                1.1.0
# executing                 2.0.1
# fastjsonschema            2.19.1
# filelock                  3.13.1
# fitparse                  1.2.0
# fonttools                 4.47.2
# formulaic                 1.0.2
# fqdn                      1.5.1
# frozenlist                1.4.1
# fsspec                    2024.6.1
# future                    1.0.0
# gpxpy                     1.6.2
# guessit                   3.8.0
# h11                       0.14.0
# httpcore                  1.0.5
# httpx                     0.27.0
# idna                      3.6
# interface-meta            1.3.0
# ipykernel                 6.29.4
# ipython                   8.25.0
# ISLP                      0.4.0
# isoduration               20.11.0
# jedi                      0.19.1
# Jinja2                    3.1.4
# joblib                    1.4.2
# json5                     0.9.25
# jsonpointer               3.0.0
# jsonschema                4.22.0
# jsonschema-specifications 2023.12.1
# jupyter_client            8.6.2
# jupyter_core              5.7.2
# jupyter-events            0.10.0
# jupyter-lsp               2.2.5
# jupyter_server            2.14.2
# jupyter_server_terminals  0.5.3
# jupyterlab                4.2.4
# jupyterlab_pygments       0.3.0
# jupyterlab_server         2.27.3
# jupyterlab-vim            4.1.3
# kiwisolver                1.4.5
# lifelines                 0.29.0
# lightning-utilities       0.11.6
# lxml                      5.3.0
# MarkupSafe                2.1.5
# matplotlib                3.8.2
# matplotlib-inline         0.1.7
# mistune                   3.0.2
# mpmath                    1.3.0
# multidict                 6.0.5
# mysql-connector-python    9.0.0
# nbclient                  0.10.0
# nbconvert                 7.16.4
# nbformat                  5.10.4
# nest-asyncio              1.6.0
# networkx                  3.3
# notebook                  7.2.1
# notebook_shim             0.2.4
# numpy                     1.26.3
# openpyxl                  3.1.3
# overrides                 7.7.0
# packaging                 23.2
# pandas                    2.2.0
# pandocfilters             1.5.1
# parso                     0.8.4
# patsy                     0.5.6
# pbr                       6.0.0
# pillow                    10.2.0
# pip                       24.2
# platformdirs              4.1.0
# progressbar2              4.4.2
# prometheus_client         0.20.0
# prompt_toolkit            3.0.46
# psutil                    5.9.8
# pure-eval                 0.2.2
# pyarrow                   16.1.0
# pycparser                 2.22
# pygam                     0.9.1
# Pygments                  2.18.0
# pyparsing                 3.1.1
# pyproject-toml            0.0.10
# pysrt                     1.1.2
# python-dateutil           2.8.2
# python-json-logger        2.0.7
# python-utils              3.8.2
# pytorch-lightning         2.4.0
# pytz                      2023.3.post1
# pywin32                   306
# pywinpty                  2.0.13
# PyYAML                    6.0.2
# pyzmq                     26.0.3
# rarfile                   4.1
# rebulk                    3.2.0
# referencing               0.35.1
# requests                  2.31.0
# rfc3339-validator         0.1.4
# rfc3986-validator         0.1.1
# rpds-py                   0.18.1
# scikit-learn              1.5.0
# scipy                     1.11.4
# seaborn                   0.13.1
# Send2Trash                1.8.3
# setuptools                70.0.0
# six                       1.16.0
# sniffio                   1.3.1
# soupsieve                 2.5
# stack-data                0.6.3
# statsmodels               0.14.1
# stevedore                 5.1.0
# subliminal                2.1.0
# sympy                     1.13.2
# terminado                 0.18.1
# threadpoolctl             3.5.0
# tinycss2                  1.3.0
# toml                      0.10.2
# torch                     2.4.0
# torchmetrics              1.4.1
# tornado                   6.4.1
# tqdm                      4.66.5
# traitlets                 5.14.3
# types-python-dateutil     2.9.0.20240316
# typing_extensions         4.12.2
# tzdata                    2023.4
# uri-template              1.3.0
# urllib3                   2.1.0
# virtualenv                20.25.0
# wcwidth                   0.2.13
# webcolors                 24.8.0
# webencodings              0.5.1
# websocket-client          1.8.0
# wheel                     0.43.0
# wrapt                     1.16.0
# XlsxWriter                3.2.0
# yarl                      1.9.4

# %%
import gzip
import os
from fitparse import FitFile
import gpxpy
import pandas as pd
from datetime import datetime, timedelta

# %%
def read_fit_file(file_path):
    with gzip.open(file_path,'rb') as gz_file:
        fit_data = gz_file.read()

    fitfile = FitFile(fit_data)
    
    records = []
    for record in fitfile.get_messages("record"):
        record_data = {}
        for record_data_entry in record:
            record_data[record_data_entry.name] = record_data_entry.value
        records.append(record_data)
    
    df = pd.DataFrame(records)
    return df

# %%
foo = read_fit_file('../Data/activities/12098685657.fit.gz')
foo.head(10)
# Out:
#    distance           timestamp  enhanced_altitude  enhanced_speed  \
# 0       0.0 2024-04-26 23:45:50                NaN             NaN
# 1       NaN 2024-04-26 23:45:51              102.2           0.025
# 2       NaN 2024-04-26 23:45:52              102.0           0.244
# 3       NaN 2024-04-26 23:45:53              102.0           0.457
# 4       NaN 2024-04-26 23:45:54              102.0           0.867
# 5       NaN 2024-04-26 23:45:55              102.0           0.926
# 6       NaN 2024-04-26 23:45:56              102.2           0.912
# 7       NaN 2024-04-26 23:45:57              102.4           0.830
# 8       NaN 2024-04-26 23:45:58              102.6           0.829
# 9       NaN 2024-04-26 23:45:59              102.8           0.788
#
#    gps_accuracy  position_lat  position_long  speed  heart_rate
# 0           NaN           NaN            NaN    NaN         NaN
# 1           2.0    38415403.0   1.214125e+09  0.025         NaN
# 2           2.0    38415417.0   1.214125e+09  0.244       110.0
# 3           2.0    38415443.0   1.214125e+09  0.457         NaN
# 4           2.0    38415472.0   1.214125e+09  0.867         NaN
# 5           1.0    38415507.0   1.214126e+09  0.926       113.0
# 6           1.0    38415547.0   1.214126e+09  0.912         NaN
# 7           1.0    38415579.0   1.214126e+09  0.830         NaN
# 8           1.0    38415599.0   1.214126e+09  0.829         NaN
# 9           1.0    38415605.0   1.214126e+09  0.788         NaN

# %% [markdown]
# # Besides the GPS data, there is not much info thats any better than the activities.csv file. Will not be using this.
